# %% [markdown]
# <a href="https://colab.research.google.com/github/Aash77-b/google-col/blob/main/data_cleaning_and_featuring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/data (1).csv')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.shape
# Out:
# (169, 4)

# %% [markdown]
# num of row

# %%
df.shape[0]
# Out:
# 169

# %%
df.shape[1]
# Out:
# 4

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %% [markdown]
# how many nulls and **not**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %% [markdown]
# handling null values

# %%
df = df.dropna(subset=['Calories'])
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
df.isnull().sum()
df.shape
# Out:
# (164, 4)

# %% [markdown]
# handling duplicated values

# %%
duplicate_data = df[df.duplicated(keep=False)]
display(duplicate_data)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 5          60    102       127     300.0
# 16         60    100       120     300.0
# 31         45     90       112     180.1
# 36         60    102       127     300.0
# 37         60    100       120     300.0
# 38         60    100       120     300.0
# 40         45     90       112     180.1
# 46         60    109       153     387.6
# 71         60    109       153     387.6
# 84         45    100       120     225.3
# 113        45    100       120     225.3
# 124        60    111       151     368.5
# 155        60    111       151     368.5

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (157, 4)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Duration'], df['Calories'])

# %% [markdown]
# outlier detection

# %%
plt.scatter(df['Duration'], df['Calories'])

# %%
df=df[df['Duration']<=192]
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  153.000000  153.000000  153.000000   153.000000
# mean    59.738562  107.803922  133.986928   347.075163
# std     31.983707   14.838631   16.181531   182.484910
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.700000
# 50%     60.000000  106.000000  131.000000   318.000000
# 75%     60.000000  112.000000  141.000000   382.800000
# max    180.000000  159.000000  182.000000  1115.000000

# %%
df[df['Pulse'] > df['Maxpulse']]
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 22        60    130       101     300.0
# 88        45    129       103     242.0
